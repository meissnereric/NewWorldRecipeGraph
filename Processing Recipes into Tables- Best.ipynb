# %% [markdown]
# # Parsing Recipe Json blobs into fun data frames!
# ## By: Tanek17 (Eric Meissner)

# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import json

# %%
df = pd.read_csv("data/recipes_json_blobs.csv")

# %% [markdown]
# ### Recipe Table

# %%
raw_recipe_table = df.apply(lambda row: pd.read_json(row['recipe'])['data'], axis=1)

# %%
raw_recipe_table.iloc[0]['ingredients'][0]['name']
# Out:
# 'Ironwood Planks'

# %% [markdown]
# Next we want to strip the outputs and ingredients columns down to just their ids, since we're going to create and link an item table to this data for our real stuff.

# %%
def process(x):
    if 'id' in x:
        if 'name' in x:
            return x['id'], x['name'], x['quantity'], x['rarity']
        else:
            return x['id'], x['id'], x['quantity'], x['rarity']
    else:
        # General category
        rarity = [s for s in x['name'].split() if s.isdigit()]
        if len(rarity) > 1:
            print("More than one potential tier?", x['name'], rarity)
        return x['name'], x['name'], x['quantity'], rarity
    
def process_output(x):
    print("X: ", x)
    return x['id'], x['name']

def process_links(x):
    if 'id' in x:
        return {}
    else:
        ingredients_in_list = [process(x) for x in x['subIngredients']]
        return {x['name']: ingredients_in_list}

# %%
row_ing = [{'type': 'item', 'itemType': 'Resource', 'id': 'timbert5', 'name': 'Ironwood Planks', 'rarity': 0, 'icon': 'TimberT5', 'quantity': 25}, {'type': 'item', 'itemType': 'Resource', 'id': 'ingott5', 'name': 'Orichalcum Ingot', 'rarity': 0, 'icon': 'IngotT5', 'quantity': 20}, {'type': 'item', 'itemType': 'Resource', 'id': 'woodstaint5', 'name': 'Mahogany Stain', 'rarity': 3, 'icon': 'WoodStainT5', 'quantity': 1}, {'type': 'item', 'itemType': 'HousingItem', 'id': 'house_housingitem_fishing_veryrarefish_c1', 'name': 'Taxidermied Daemonaja', 'rarity': 3, 'icon': 'House_HousingItem_Fishing_VeryRareFish_C1', 'quantity': 1}, {'type': 'item', 'itemType': 'HousingItem', 'id': 'house_housingitem_buff_fishing_bonus_t2', 'name': 'Basic Fishing Gathering Trophy', 'rarity': 2, 'icon': 'House_HousingItem_Buff_Fishing_Bonus_T2', 'quantity': 1}]
row_ing2 = [{'type': 'category', 'name': 'Tier 5 Metals', 'icon': 'icons/items/drawing/ingot', 'quantity': 6, 'subIngredients': [{'type': 'item', 'itemType': 'Resource', 'id': 'ingott5', 'name': 'Orichalcum Ingot', 'rarity': 0, 'icon': 'IngotT5', 'quantity': 6, 'gsMaxBonus': 0, 'gsMinBonus': 0}, {'type': 'item', 'itemType': 'Resource', 'id': 'tolviumt1', 'name': 'Tolvium', 'rarity': 4, 'icon': 'OreT4', 'quantity': 6, 'gsMaxBonus': 5, 'gsMinBonus': 5}, {'type': 'item', 'itemType': 'Resource', 'id': 'cinnabart1', 'name': 'Cinnabar', 'rarity': 4, 'icon': 'MI_CorruptedMoss', 'quantity': 6, 'gsMaxBonus': 5, 'gsMinBonus': 5}, {'type': 'item', 'itemType': 'Resource', 'id': 'ingott51', 'name': 'Asmodeum', 'rarity': 3, 'icon': 'IngotT51', 'quantity': 6, 'gsMaxBonus': 15, 'gsMinBonus': 15}]}, {'type': 'category', 'name': 'Leathers', 'icon': 'icons/items/drawing/leather', 'quantity': 2, 'subIngredients': [{'type': 'item', 'itemType': 'Resource', 'id': 'leathert5', 'name': 'Infused Leather', 'rarity': 0, 'icon': 'LeatherT5', 'quantity': 2, 'gsMaxBonus': 0, 'gsMinBonus': 0}, {'type': 'item', 'itemType': 'Resource', 'id': 'leathert2', 'name': 'Coarse Leather', 'rarity': 0, 'icon': 'LeatherT2', 'quantity': 2, 'gsMaxBonus': 0, 'gsMinBonus': -15}, {'type': 'item', 'itemType': 'Resource', 'id': 'ragehidet1', 'name': 'Ragehide', 'rarity': 1, 'icon': 'RawhideT1', 'quantity': 2, 'gsMaxBonus': 5, 'gsMinBonus': -10}, {'type': 'item', 'itemType': 'Resource', 'id': 'leathert3', 'name': 'Rugged Leather', 'rarity': 0, 'icon': 'LeatherT3', 'quantity': 2, 'gsMaxBonus': 0, 'gsMinBonus': -10}, {'type': 'item', 'itemType': 'Resource', 'id': 'shadowfurt1', 'name': 'Shadowfur', 'rarity': 2, 'icon': 'RawhideT4', 'quantity': 2, 'gsMaxBonus': 5, 'gsMinBonus': -5}, {'type': 'item', 'itemType': 'Resource', 'id': 'scalyhidet1', 'name': 'Scaly Hide', 'rarity': 0, 'icon': 'ScalyHideT1', 'quantity': 2, 'gsMaxBonus': 0, 'gsMinBonus': -5}, {'type': 'item', 'itemType': 'Resource', 'id': 'leathert4', 'name': 'Layered Leather', 'rarity': 0, 'icon': 'LeatherT4', 'quantity': 2, 'gsMaxBonus': 0, 'gsMinBonus': -5}, {'type': 'item', 'itemType': 'Resource', 'id': 'shifthidet1', 'name': 'Shifthide', 'rarity': 3, 'icon': 'MangyHideT1', 'quantity': 2, 'gsMaxBonus': 5, 'gsMinBonus': 0}, {'type': 'item', 'itemType': 'Resource', 'id': 'brightscalehidet1', 'name': 'Brightscale Hide', 'rarity': 3, 'icon': 'RawhideT5', 'quantity': 2, 'gsMaxBonus': 5, 'gsMinBonus': 0}, {'type': 'item', 'itemType': 'Resource', 'id': 'scarhidet1', 'name': 'Scarhide', 'rarity': 4, 'icon': 'MangyHideT3', 'quantity': 2, 'gsMaxBonus': 5, 'gsMinBonus': 5}, {'type': 'item', 'itemType': 'Resource', 'id': 'smolderhidet1', 'name': 'Smolderhide', 'rarity': 4, 'icon': 'MangyHideT2', 'quantity': 2, 'gsMaxBonus': 5, 'gsMinBonus': 5}, {'type': 'item', 'itemType': 'Resource', 'id': 'leathert51', 'name': 'Runic Leather', 'rarity': 3, 'icon': 'LeatherT51', 'quantity': 2, 'gsMaxBonus': 15, 'gsMinBonus': 15}]}, {'type': 'category', 'name': 'Cloth', 'icon': 'icons/items/drawing/cloth', 'quantity': 1, 'subIngredients': [{'type': 'item', 'itemType': 'Resource', 'id': 'clotht5', 'name': 'Infused Silk', 'rarity': 0, 'icon': 'ClothT5', 'quantity': 1, 'gsMaxBonus': 0, 'gsMinBonus': 0}, {'type': 'item', 'itemType': 'Resource', 'id': 'clotht2', 'name': 'Linen', 'rarity': 0, 'icon': 'ClothT2', 'quantity': 1, 'gsMaxBonus': 0, 'gsMinBonus': -15}, {'type': 'item', 'itemType': 'Resource', 'id': 'shadeclotht1', 'name': 'Shadecloth', 'rarity': 1, 'icon': 'CorruptedClothT1', 'quantity': 1, 'gsMaxBonus': 5, 'gsMinBonus': -10}, {'type': 'item', 'itemType': 'Resource', 'id': 'clotht3', 'name': 'Sateen', 'rarity': 0, 'icon': 'ClothT3', 'quantity': 1, 'gsMaxBonus': 0, 'gsMinBonus': -10}, {'type': 'item', 'itemType': 'Resource', 'id': 'phasefibert1', 'name': 'Phasefiber', 'rarity': 2, 'icon': 'FiberT4', 'quantity': 1, 'gsMaxBonus': 5, 'gsMinBonus': -5}, {'type': 'item', 'itemType': 'Resource', 'id': 'clotht4', 'name': 'Silk', 'rarity': 0, 'icon': 'ClothT4', 'quantity': 1, 'gsMaxBonus': 0, 'gsMinBonus': -5}, {'type': 'item', 'itemType': 'Resource', 'id': 'scalecordt1', 'name': 'Scalecord', 'rarity': 3, 'icon': 'MI_NeedleAndThread', 'quantity': 1, 'gsMaxBonus': 5, 'gsMinBonus': 0}, {'type': 'item', 'itemType': 'Resource', 'id': 'glintwoolt1', 'name': 'Glintstrands', 'rarity': 3, 'icon': 'MI_TornFabric', 'quantity': 1, 'gsMaxBonus': 5, 'gsMinBonus': 0}, {'type': 'item', 'itemType': 'Resource', 'id': 'scaleclotht1', 'name': 'Scalecloth', 'rarity': 4, 'icon': 'MI_Cloak', 'quantity': 1, 'gsMaxBonus': 5, 'gsMinBonus': 5}, {'type': 'item', 'itemType': 'Resource', 'id': 'blisterweavet1', 'name': 'Blisterweave', 'rarity': 4, 'icon': 'CorruptedClothT3', 'quantity': 1, 'gsMaxBonus': 5, 'gsMinBonus': 5}, {'type': 'item', 'itemType': 'Resource', 'id': 'clotht51', 'name': 'Phoenixweave', 'rarity': 3, 'icon': 'ClothT51', 'quantity': 1, 'gsMaxBonus': 15, 'gsMinBonus': 15}]}]


## Tests
l1 = list(map(lambda x: process(x), row_ing))
l2 = list(map(lambda x: process(x), row_ing2))
l3 = list(map(lambda x: process_links(x), row_ing2))

from collections import ChainMap
result = dict(ChainMap(*l3))
print(l1 + l2)
print('l3', l3)
print('result', result)
# Out:
# [('timbert5', 'Ironwood Planks', 25, 0), ('ingott5', 'Orichalcum Ingot', 20, 0), ('woodstaint5', 'Mahogany Stain', 1, 3), ('house_housingitem_fishing_veryrarefish_c1', 'Taxidermied Daemonaja', 1, 3), ('house_housingitem_buff_fishing_bonus_t2', 'Basic Fishing Gathering Trophy', 1, 2), ('Tier 5 Metals', 'Tier 5 Metals', 6, ['5']), ('Leathers', 'Leathers', 2, []), ('Cloth', 'Cloth', 1, [])]
# l3 [{'Tier 5 Metals': [('ingott5', 'Orichalcum Ingot', 6, 0), ('tolviumt1', 'Tolvium', 6, 4), ('cinnabart1', 'Cinnabar', 6, 4), ('ingott51', 'Asmodeum', 6, 3)]}, {'Leathers': [('leathert5', 'Infused Leather', 2, 0), ('leathert2', 'Coarse Leather', 2, 0), ('ragehidet1', 'Ragehide', 2, 1), ('leathert3', 'Rugged Leather', 2, 0), ('shadowfurt1', 'Shadowfur', 2, 2), ('scalyhidet1', 'Scaly Hide', 2, 0), ('leathert4', 'Layered Leather', 2, 0), ('shifthidet1', 'Shifthide', 2, 3), ('brightscalehidet1', 'Brightscale Hide', 2, 3), ('scarhidet1', 'Scarhide', 2, 4), ('smolderhidet1', 'Smolderhide', 2, 4), ('leathert51', 'Runic Leather', 2, 3)]}, {'Cloth': [('clotht5', 'Infused Silk', 1, 0), ('clotht2', 'Linen', 1, 0), ('shadeclotht1', 'Shadecloth', 1, 1), ('clotht3', 'Sateen', 1, 0), ('phasefibert1', 'Phasefiber', 1, 2), ('clotht4', 'Silk', 1, 0), ('scalecordt1', 'Scalecord', 1, 3), ('glintwoolt1', 'Glintstrands', 1, 3), ('scaleclotht1', 'Scalecloth', 1, 4), ('blisterweavet1', 'Blisterweave', 1, 4), ('clotht51', 'Phoenixweave', 1, 3)]}]
# result {'Cloth': [('clotht5', 'Infused Silk', 1, 0), ('clotht2', 'Linen', 1, 0), ('shadeclotht1', 'Shadecloth', 1, 1), ('clotht3', 'Sateen', 1, 0), ('phasefibert1', 'Phasefiber', 1, 2), ('clotht4', 'Silk', 1, 0), ('scalecordt1', 'Scalecord', 1, 3), ('glintwoolt1', 'Glintstrands', 1, 3), ('scaleclotht1', 'Scalecloth', 1, 4), ('blisterweavet1', 'Blisterweave', 1, 4), ('clotht51', 'Phoenixweave', 1, 3)], 'Leathers': [('leathert5', 'Infused Leather', 2, 0), ('leathert2', 'Coarse Leather', 2, 0), ('ragehidet1', 'Ragehide', 2, 1), ('leathert3', 'Rugged Leather', 2, 0), ('shadowfurt1', 'Shadowfur', 2, 2), ('scalyhidet1', 'Scaly Hide', 2, 0), ('leathert4', 'Layered Leather', 2, 0), ('shifthidet1', 'Shifthide', 2, 3), ('brightscalehidet1', 'Brightscale Hide', 2, 3), ('scarhidet1', 'Scarhide', 2, 4), ('smolderhidet1', 'Smolderhide', 2, 4), ('leathert51', 'Runic Leather', 2, 3)], 'Tier 5 Metals': [('ingott5', 'Orichalcum Ingot', 6, 0), ('tolviumt1', 'Tolvium', 6, 4), ('cinnabart1', 'Cinnabar', 6, 4), ('ingott51', 'Asmodeum', 6, 3)]}

# %%
linked_recipe_table = raw_recipe_table.copy(deep=True)
linked_recipe_table['ingredients'] = raw_recipe_table.apply(lambda row: json.dumps(list(map(lambda x: process(x), row['ingredients']))), axis=1)
linked_recipe_table['output'] = raw_recipe_table.apply(lambda row: row['output']['id'], axis=1)

# %%
linked_recipe_table
# Out:
#       BaseGearScore             category                            cooldown  \
# 0               NaN            Furniture                                 NaN
# 1               NaN            Furniture                                 NaN
# 2               NaN            Furniture                                 NaN
# 3               NaN            Furniture                                 NaN
# 4               NaN            Furniture                                 NaN
# 5               NaN            Furniture                                 NaN
# 6               NaN            Furniture                                 NaN
# 7               NaN            Furniture                                 NaN
# 8               NaN            Furniture                                 NaN
# 9               NaN            Furniture                                 NaN
# 10              NaN                Armor                                 NaN
# 11              NaN            Furniture                                 NaN
# 12              NaN                Armor                                 NaN
# 13              NaN                Armor                                 NaN
# 14              NaN  Crafting Components                                 NaN
# 15              NaN  Crafting Components                                 NaN
# 16              NaN              Weapons                                 NaN
# 17              NaN              Weapons                                 NaN
# 18              NaN              Weapons                                 NaN
# 19              NaN              Weapons                                 NaN
# 20              NaN              Weapons                                 NaN
# 21              NaN            Furniture                                 NaN
# 22              NaN              Weapons                                 NaN
# 23              NaN              Weapons                                 NaN
# 24              NaN              Weapons                                 NaN
# 25              NaN              Weapons                                 NaN
# 26              NaN            Furniture                                 NaN
# 27              NaN              Weapons                                 NaN
# 28            500.0                Armor                                 NaN
# 29            500.0                Armor                                 NaN
# ...             ...                  ...                                 ...
# 2619            NaN              Weapons                                 NaN
# 2620            NaN              Weapons                                 NaN
# 2621            NaN            Furniture                                 NaN
# 2622            NaN              Weapons                                 NaN
# 2623            NaN            Furniture                                 NaN
# 2624            NaN              Weapons                                 NaN
# 2625            NaN    Refined Resources  {'seconds': 86400, 'quantity': 10}
# 2626            NaN            Furniture                                 NaN
# 2627            NaN            Furniture                                 NaN
# 2628            NaN            Furniture                                 NaN
# 2629            NaN  Crafting Components                                 NaN
# 2630            NaN                Armor                                 NaN
# 2631            NaN                Armor                                 NaN
# 2632            NaN    Refined Resources  {'seconds': 86400, 'quantity': 10}
# 2633            NaN                Armor                                 NaN
# 2634            NaN  Crafting Components                                 NaN
# 2635            NaN                Armor                                 NaN
# 2636            NaN                Armor                                 NaN
# 2637            NaN    Refined Resources  {'seconds': 86400, 'quantity': 10}
# 2638            NaN    Refined Resources  {'seconds': 86400, 'quantity': 10}
# 2639            NaN                Armor                                 NaN
# 2640            NaN                Armor                                 NaN
# 2641            NaN            Cut Stone  {'seconds': 86400, 'quantity': 10}
# 2642            NaN              Weapons                                 NaN
# 2643            NaN              Weapons                                 NaN
# 2644            NaN              Weapons                                 NaN
# 2645            NaN            Furniture                                 NaN
# 2646            NaN            Furniture                                 NaN
# 2647            NaN                Armor                                 NaN
# 2648            NaN            Furniture                                 NaN
#
#                                             description  \
# 0     Crafting recipe for Major Fishing Gathering Tr...
# 1     Crafting recipe for Major Harvesting Gathering...
# 2     Crafting recipe for Major Logging Gathering Tr...
# 3            Crafting recipe for Major Loot Luck Trophy
# 4          Crafting recipe for Major Lost Combat Trophy
# 5     Crafting recipe for Major Cooking Crafting Trophy
# 6     Crafting recipe for Major Corrupted Combat Trophy
# 7     Crafting recipe for Major Engineering Crafting...
# 8     Crafting recipe for Major Mining Gathering Trophy
# 9     Crafting recipe for Major Skinning Gathering T...
# 10                     Crafting recipe for Voidbent Hat
# 11    Crafting recipe for Major Armoring Crafting Tr...
# 12                Crafting recipe for Voidbent Sabatons
# 13                    Crafting recipe for Voidbent Coat
# 14                   Crafting recipe for Asmodeum Chain
# 15                 Crafting recipe for Asmodeum Setting
# 16             Crafting recipe for Voidforged Harbinger
# 17                       Crafting recipe for Yul'kithir
# 18                         Crafting recipe for Dark Sky
# 19             Crafting recipe for Voidbringer's Rapier
# 20                   Crafting recipe for Gilded Defense
# 21    Crafting recipe for Major Angry Earth Combat T...
# 22             Crafting recipe for Shield of Suppresion
# 23                 Crafting recipe for Soulforged Spear
# 24                         Crafting recipe for Warpwood
# 25           Crafting recipe for Musket of Unseen Power
# 26     Crafting recipe for Major Wildlife Combat Trophy
# 27                 Crafting recipe for Axe of the Abyss
# 28       Crafting recipe for Fur-Lined Orichalcum Boots
# 29            Crafting recipe for Beasthunter Footwraps
# ...                                                 ...
# 2619                  Crafting recipe for Sacred Demise
# 2620          Crafting recipe for Enchanted Flame Staff
# 2621   Crafting recipe for Black-lacquered Low Bookcase
# 2622                     Crafting recipe for Pestilence
# 2623           Crafting recipe for Seafoam Posh Valance
# 2624                    Crafting recipe for The Lookout
# 2625                       Crafting recipe for Asmodeum
# 2626     Crafting recipe for Well-polished Tall Dresser
# 2627    Crafting recipe for Well-polished Short Dresser
# 2628  Crafting recipe for Black-lacquered Short Dresser
# 2629                  Crafting recipe for Asmodeum Hook
# 2630              Crafting recipe for Voidbent Leggings
# 2631                 Crafting recipe for Voidbent Grips
# 2632                  Crafting recipe for Runic Leather
# 2633                 Crafting recipe for Voidbent Wraps
# 2634                  Crafting recipe for Asmodeum Band
# 2635                Crafting recipe for Voidbent Gloves
# 2636                 Crafting recipe for Voidbent Robes
# 2637                   Crafting recipe for Phoenixweave
# 2638               Crafting recipe for Glittering Ebony
# 2639                 Crafting recipe for Voidbent Pants
# 2640                 Crafting recipe for Voidbent Boots
# 2641                      Crafting recipe for Runestone
# 2642         Crafting recipe for Gortan's Tainted Staff
# 2643                   Crafting recipe for Meteor Trail
# 2644              Crafting recipe for Crystalline Curse
# 2645     Crafting recipe for Golden Steel Storage Chest
# 2646   Crafting recipe for Major Arcana Crafting Trophy
# 2647                 Crafting recipe for Voidbent Shoes
# 2648  Crafting recipe for Major Weaponsmithing Craft...
#
#                                                   event  \
# 0     {'CategoricalProgressionId': 'Furnishing', 'Ca...
# 1     {'CategoricalProgressionId': 'Furnishing', 'Ca...
# 2     {'CategoricalProgressionId': 'Furnishing', 'Ca...
# 3     {'CategoricalProgressionId': 'Furnishing', 'Ca...
# 4     {'CategoricalProgressionId': 'Furnishing', 'Ca...
# 5     {'CategoricalProgressionId': 'Furnishing', 'Ca...
# 6     {'CategoricalProgressionId': 'Furnishing', 'Ca...
# 7     {'CategoricalProgressionId': 'Furnishing', 'Ca...
# 8     {'CategoricalProgressionId': 'Furnishing', 'Ca...
# 9     {'CategoricalProgressionId': 'Furnishing', 'Ca...
# 10    {'CategoricalProgressionId': 'Armoring', 'Cate...
# 11    {'CategoricalProgressionId': 'Furnishing', 'Ca...
# 12    {'CategoricalProgressionId': 'Armoring', 'Cate...
# 13    {'CategoricalProgressionId': 'Armoring', 'Cate...
# 14    {'CategoricalProgressionId': 'Jewelcrafting', ...
# 15    {'CategoricalProgressionId': 'Jewelcrafting', ...
# 16    {'CategoricalProgressionId': 'Weaponsmithing',...
# 17    {'CategoricalProgressionId': 'Weaponsmithing',...
# 18    {'CategoricalProgressionId': 'Weaponsmithing',...
# 19    {'CategoricalProgressionId': 'Weaponsmithing',...
# 20    {'CategoricalProgressionId': 'Weaponsmithing',...
# 21    {'CategoricalProgressionId': 'Furnishing', 'Ca...
# 22    {'CategoricalProgressionId': 'Weaponsmithing',...
# 23    {'CategoricalProgressionId': 'Engineering', 'C...
# 24    {'CategoricalProgressionId': 'Engineering', 'C...
# 25    {'CategoricalProgressionId': 'Engineering', 'C...
# 26    {'CategoricalProgressionId': 'Furnishing', 'Ca...
# 27    {'CategoricalProgressionId': 'Engineering', 'C...
# 28    {'CategoricalProgressionId': 'Armoring', 'Cate...
# 29    {'CategoricalProgressionId': 'Armoring', 'Cate...
# ...                                                 ...
# 2619  {'CategoricalProgressionId': 'Weaponsmithing',...
# 2620  {'CategoricalProgressionId': 'Arcana', 'Catego...
# 2621  {'CategoricalProgressionId': 'Furnishing', 'Ca...
# 2622  {'CategoricalProgressionId': 'Weaponsmithing',...
# 2623  {'CategoricalProgressionId': 'Furnishing', 'Ca...
# 2624  {'CategoricalProgressionId': 'Engineering', 'C...
# 2625  {'CategoricalProgressionId': 'Smelting', 'Cate...
# 2626  {'CategoricalProgressionId': 'Furnishing', 'Ca...
# 2627  {'CategoricalProgressionId': 'Furnishing', 'Ca...
# 2628  {'CategoricalProgressionId': 'Furnishing', 'Ca...
# 2629  {'CategoricalProgressionId': 'Jewelcrafting', ...
# 2630  {'CategoricalProgressionId': 'Armoring', 'Cate...
# 2631  {'CategoricalProgressionId': 'Armoring', 'Cate...
# 2632  {'CategoricalProgressionId': 'Leatherworking',...
# 2633  {'CategoricalProgressionId': 'Armoring', 'Cate...
# 2634  {'CategoricalProgressionId': 'Jewelcrafting', ...
# 2635  {'CategoricalProgressionId': 'Armoring', 'Cate...
# 2636  {'CategoricalProgressionId': 'Armoring', 'Cate...
# 2637  {'CategoricalProgressionId': 'Weaving', 'Categ...
# 2638  {'CategoricalProgressionId': 'Woodworking', 'C...
# 2639  {'CategoricalProgressionId': 'Armoring', 'Cate...
# 2640  {'CategoricalProgressionId': 'Armoring', 'Cate...
# 2641  {'CategoricalProgressionId': 'Stonecutting', '...
# 2642  {'CategoricalProgressionId': 'Arcana', 'Catego...
# 2643  {'CategoricalProgressionId': 'Arcana', 'Catego...
# 2644  {'CategoricalProgressionId': 'Arcana', 'Catego...
# 2645  {'CategoricalProgressionId': 'Furnishing', 'Ca...
# 2646  {'CategoricalProgressionId': 'Furnishing', 'Ca...
# 2647  {'CategoricalProgressionId': 'Armoring', 'Cate...
# 2648  {'CategoricalProgressionId': 'Furnishing', 'Ca...
#
#                                                 icon  \
# 0            House_HousingItem_Buff_Fishing_Bonus_T3
# 1         House_HousingItem_Buff_Harvesting_Bonus_T3
# 2            House_HousingItem_Buff_Logging_Bonus_T3
# 3               House_HousingItem_Buff_Luck_Bonus_T3
# 4           House_HousingItem_Buff_Damage_Vs_Lost_T3
# 5            House_HousingItem_Buff_Cooking_Bonus_T3
# 6      House_HousingItem_Buff_Damage_Vs_Corrupted_T3
# 7        House_HousingItem_Buff_Engineering_Bonus_T3
# 8             House_HousingItem_Buff_Mining_Bonus_T3
# 9           House_HousingItem_Buff_Skinning_Bonus_T3
# 10                             m_voidbentmedium_head
# 11        House_HousingItem_Buff_Outfitting_Bonus_T3
# 12                              m_voidbentheavy_feet
# 13                            m_voidbentmedium_chest
# 14                                  Trinket_ChainT51
# 15                                Trinket_SettingT51
# 16                          1hLongsword_WidowmakerT5
# 17                         2hWarhammer_EarthshakerT2
# 18                                2hGreatAxeHeroicT5
# 19                                  1hRapierHeroicT5
# 20                             1hRoundShieldHeroicT5
# 21    House_HousingItem_Buff_Damage_Vs_AngryEarth_T3
# 22                              1hKiteShieldHeroicT5
# 23                                         2hSpearT4
# 24                                     2hBowHeroicT5
# 25                                  2hMusketHeroicT5
# 26        House_HousingItem_Buff_Damage_Vs_Beasts_T3
# 27                                 1hHatchetHeroicT5
# 28                                Feet_TrailrunnerT2
# 29                                   BeastBear_Boots
# ...                                              ...
# 2619                       2hWarhammer_EarthshakerT2
# 2620                     2hStaffFire_TormentedSoulT4
# 2621           House_HousingItem_Pirate_Bookcase01_D
# 2622                    2hGreataxe_RecklessAbandonT4
# 2623      House_HousingItem_Pirate_Decor_Curtain01_B
# 2624                                      2hBowFaeT5
# 2625                                        IngotT51
# 2626            House_HousingItem_Pirate_Cabinet02_C
# 2627            House_HousingItem_Pirate_Cabinet01_C
# 2628            House_HousingItem_Pirate_Cabinet01_D
# 2629                                 Trinket_HookT51
# 2630                           m_voidbentmedium_legs
# 2631                         m_voidbentmedium_gloves
# 2632                                      LeatherT51
# 2633                            m_voidbentlight_head
# 2634                                 Trinket_BandT51
# 2635                          m_voidbentlight_gloves
# 2636                           m_voidbentlight_chest
# 2637                                        ClothT51
# 2638                                       TimberT51
# 2639                            m_voidbentlight_legs
# 2640                           m_voidbentmedium_feet
# 2641                                        BlockT51
# 2642                     2hStaffLife_PeacefulDreamT2
# 2643                     2hStaffFire_TormentedSoulT4
# 2644                         2hicegauntletEtherealT5
# 2645         House_HousingItem_Storage_T4_ChestSteel
# 2646         House_HousingItem_Buff_Alchemy_Bonus_T3
# 2647                            m_voidbentlight_feet
# 2648   House_HousingItem_Buff_Blacksmithing_Bonus_T3
#
#                                                   id  \
# 0            house_housingitem_buff_fishing_bonus_t3
# 1         house_housingitem_buff_harvesting_bonus_t3
# 2            house_housingitem_buff_logging_bonus_t3
# 3               house_housingitem_buff_luck_bonus_t3
# 4           house_housingitem_buff_damage_vs_lost_t3
# 5            house_housingitem_buff_cooking_bonus_t3
# 6      house_housingitem_buff_damage_vs_corrupted_t3
# 7        house_housingitem_buff_engineering_bonus_t3
# 8             house_housingitem_buff_mining_bonus_t3
# 9           house_housingitem_buff_skinning_bonus_t3
# 10                             mediumhead_voidbentt5
# 11        house_housingitem_buff_outfitting_bonus_t3
# 12                              heavyfeet_voidbentt5
# 13                            mediumchest_voidbentt5
# 14                                  trinket_chaint51
# 15                                trinket_settingt51
# 16                 1hlongsword_voidforgedharbingert5
# 17                           2hwarhammer_yulkithirt5
# 18                              2hgreataxe_darkskyt5
# 19                     1hrapier_voidbringersrapiert5
# 20                      1hroundshield_heroesshieldt5
# 21    house_housingitem_buff_damage_vs_angryearth_t3
# 22                       1hkiteshield_heroicshieldt5
# 23                         2hspear_soulforgedspeart5
# 24                                  2hbow_warpwoodt5
# 25                    2hmusket_musketofunseenpowert5
# 26        house_housingitem_buff_damage_vs_beasts_t3
# 27                     1hthrowingaxe_axeoftheabysst5
# 28                              heavyfeet_furlinedt5
# 29                          mediumfeet_beasthuntert5
# ...                                              ...
# 2619                      2hwarhammer_sacreddemiset5
# 2620               2hstafffire_enchantedflamestafft5
# 2621           house_housingitem_pirate_bookcase01_d
# 2622                         2hgreataxe_pestilencet5
# 2623      house_housingitem_pirate_decor_curtain01_b
# 2624                              2hbow_thelookoutt5
# 2625                                        ingott51
# 2626            house_housingitem_pirate_cabinet02_c
# 2627            house_housingitem_pirate_cabinet01_c
# 2628            house_housingitem_pirate_cabinet01_d
# 2629                                 trinket_hookt51
# 2630                           mediumlegs_voidbentt5
# 2631                          mediumhands_voidbentt5
# 2632                                      leathert51
# 2633                            lighthead_voidbentt5
# 2634                                 trinket_bandt51
# 2635                           lighthands_voidbentt5
# 2636                           lightchest_voidbentt5
# 2637                                        clotht51
# 2638                                       timbert51
# 2639                            lightlegs_voidbentt5
# 2640                           mediumfeet_voidbentt5
# 2641                                        blockt51
# 2642               2hstafflife_gortanstaintedstafft5
# 2643                       2hstafffire_meteortrailt5
# 2644                1hgauntletice_crystallinecurset5
# 2645         house_housingitem_storage_t4_cheststeel
# 2646         house_housingitem_buff_alchemy_bonus_t3
# 2647                            lightfeet_voidbentt5
# 2648   house_housingitem_buff_blacksmithing_bonus_t3
#
#                                             ingredients     itemType  \
# 0     [["timbert5", "Ironwood Planks", 25], ["ingott...  HousingItem
# 1     [["timbert5", "Ironwood Planks", 25], ["ingott...  HousingItem
# 2     [["timbert5", "Ironwood Planks", 25], ["ingott...  HousingItem
# 3     [["timbert5", "Ironwood Planks", 25], ["ingott...  HousingItem
# 4     [["timbert5", "Ironwood Planks", 25], ["ingott...  HousingItem
# 5     [["timbert5", "Ironwood Planks", 25], ["ingott...  HousingItem
# 6     [["timbert5", "Ironwood Planks", 25], ["ingott...  HousingItem
# 7     [["timbert5", "Ironwood Planks", 25], ["ingott...  HousingItem
# 8     [["timbert5", "Ironwood Planks", 25], ["ingott...  HousingItem
# 9     [["timbert5", "Ironwood Planks", 25], ["ingott...  HousingItem
# 10    [["leathert51", "Runic Leather", 12], ["clotht...        Armor
# 11    [["timbert5", "Ironwood Planks", 25], ["ingott...  HousingItem
# 12    [["ingott51", "Asmodeum", 6], ["leathert51", "...        Armor
# 13    [["leathert51", "Runic Leather", 26], ["clotht...        Armor
# 14                        [["ingott51", "Asmodeum", 8]]     Resource
# 15                        [["ingott51", "Asmodeum", 4]]     Resource
# 16    [["ingott51", "Asmodeum", 14], ["leathert51", ...       Weapon
# 17    [["ingott51", "Asmodeum", 20], ["leathert51", ...       Weapon
# 18    [["ingott51", "Asmodeum", 20], ["leathert51", ...       Weapon
# 19    [["ingott51", "Asmodeum", 14], ["leathert51", ...       Weapon
# 20    [["ingott51", "Asmodeum", 14], ["timbert51", "...       Weapon
# 21    [["timbert5", "Ironwood Planks", 25], ["ingott...  HousingItem
# 22    [["ingott51", "Asmodeum", 14], ["timbert51", "...       Weapon
# 23    [["ingott51", "Asmodeum", 20], ["timbert51", "...       Weapon
# 24    [["timbert51", "Glittering Ebony", 20], ["clot...       Weapon
# 25    [["ingott51", "Asmodeum", 20], ["timbert51", "...       Weapon
# 26    [["timbert5", "Ironwood Planks", 25], ["ingott...  HousingItem
# 27    [["ingott51", "Asmodeum", 14], ["leathert51", ...       Weapon
# 28    [["Tier 5 Metals", null, 6], ["Leathers", null...        Armor
# 29    [["Tier 5 Leather", null, 6], ["Cloth", null, ...        Armor
# ...                                                 ...          ...
# 2619  [["ingott51", "Asmodeum", 20], ["leathert51", ...       Weapon
# 2620  [["essencefiret1", "Fire Quintessence", 20], [...       Weapon
# 2621  [["timbert5", "Ironwood Planks", 30], ["ingott...  HousingItem
# 2622  [["ingott51", "Asmodeum", 20], ["leathert51", ...       Weapon
# 2623  [["clotht5", "Infused Silk", 15], ["ingott5", ...  HousingItem
# 2624  [["timbert51", "Glittering Ebony", 20], ["clot...       Weapon
# 2625  [["ingott5", "Orichalcum Ingot", 5], ["tolvium...     Resource
# 2626  [["timbert5", "Ironwood Planks", 30], ["ingott...  HousingItem
# 2627  [["timbert5", "Ironwood Planks", 30], ["ingott...  HousingItem
# 2628  [["timbert5", "Ironwood Planks", 30], ["ingott...  HousingItem
# 2629                      [["ingott51", "Asmodeum", 8]]     Resource
# 2630  [["leathert51", "Runic Leather", 12], ["clotht...        Armor
# 2631  [["leathert51", "Runic Leather", 6], ["clotht5...        Armor
# 2632  [["leathert5", "Infused Leather", 5], ["smolde...     Resource
# 2633  [["clotht51", "Phoenixweave", 12], ["leathert5...        Armor
# 2634                      [["ingott51", "Asmodeum", 8]]     Resource
# 2635  [["clotht51", "Phoenixweave", 6], ["leathert51...        Armor
# 2636  [["clotht51", "Phoenixweave", 26], ["leathert5...        Armor
# 2637  [["clotht5", "Infused Silk", 5], ["scaleclotht...     Resource
# 2638  [["timbert5", "Ironwood Planks", 5], ["wildwoo...     Resource
# 2639  [["clotht51", "Phoenixweave", 12], ["leathert5...        Armor
# 2640  [["leathert51", "Runic Leather", 6], ["clotht5...        Armor
# 2641  [["blockt5", "Obsidian Voidstone", 5], ["sandp...     Resource
# 2642  [["essencelifet1", "Life Quintessence", 20], [...       Weapon
# 2643  [["essencefiret1", "Fire Quintessence", 20], [...       Weapon
# 2644  [["essencewatert1", "Water Quintessence", 20],...       Weapon
# 2645  [["timbert5", "Ironwood Planks", 30], ["ingott...  HousingItem
# 2646  [["timbert5", "Ironwood Planks", 25], ["ingott...  HousingItem
# 2647  [["clotht51", "Phoenixweave", 6], ["leathert51...        Armor
# 2648  [["timbert5", "Ironwood Planks", 25], ["ingott...  HousingItem
#
#                                               name  \
# 0           Recipe: Major Fishing Gathering Trophy
# 1        Recipe: Major Harvesting Gathering Trophy
# 2           Recipe: Major Logging Gathering Trophy
# 3                   Recipe: Major Loot Luck Trophy
# 4                 Recipe: Major Lost Combat Trophy
# 5            Recipe: Major Cooking Crafting Trophy
# 6            Recipe: Major Corrupted Combat Trophy
# 7        Recipe: Major Engineering Crafting Trophy
# 8            Recipe: Major Mining Gathering Trophy
# 9          Recipe: Major Skinning Gathering Trophy
# 10                            Recipe: Voidbent Hat
# 11          Recipe: Major Armoring Crafting Trophy
# 12                       Recipe: Voidbent Sabatons
# 13                           Recipe: Voidbent Coat
# 14                          Recipe: Asmodeum Chain
# 15                        Recipe: Asmodeum Setting
# 16                    Recipe: Voidforged Harbinger
# 17                              Recipe: Yul'kithir
# 18                                Recipe: Dark Sky
# 19                    Recipe: Voidbringer's Rapier
# 20                          Recipe: Gilded Defense
# 21         Recipe: Major Angry Earth Combat Trophy
# 22                    Recipe: Shield of Suppresion
# 23                        Recipe: Soulforged Spear
# 24                                Recipe: Warpwood
# 25                  Recipe: Musket of Unseen Power
# 26            Recipe: Major Wildlife Combat Trophy
# 27                        Recipe: Axe of the Abyss
# 28              Recipe: Fur-Lined Orichalcum Boots
# 29                   Recipe: Beasthunter Footwraps
# ...                                            ...
# 2619                         Recipe: Sacred Demise
# 2620                 Recipe: Enchanted Flame Staff
# 2621          Recipe: Black-lacquered Low Bookcase
# 2622                            Recipe: Pestilence
# 2623                  Recipe: Seafoam Posh Valance
# 2624                           Recipe: The Lookout
# 2625                              Recipe: Asmodeum
# 2626            Recipe: Well-polished Tall Dresser
# 2627           Recipe: Well-polished Short Dresser
# 2628         Recipe: Black-lacquered Short Dresser
# 2629                         Recipe: Asmodeum Hook
# 2630                     Recipe: Voidbent Leggings
# 2631                        Recipe: Voidbent Grips
# 2632                         Recipe: Runic Leather
# 2633                        Recipe: Voidbent Wraps
# 2634                         Recipe: Asmodeum Band
# 2635                       Recipe: Voidbent Gloves
# 2636                        Recipe: Voidbent Robes
# 2637                          Recipe: Phoenixweave
# 2638                      Recipe: Glittering Ebony
# 2639                        Recipe: Voidbent Pants
# 2640                        Recipe: Voidbent Boots
# 2641                             Recipe: Runestone
# 2642                Recipe: Gortan's Tainted Staff
# 2643                          Recipe: Meteor Trail
# 2644                     Recipe: Crystalline Curse
# 2645            Recipe: Golden Steel Storage Chest
# 2646          Recipe: Major Arcana Crafting Trophy
# 2647                        Recipe: Voidbent Shoes
# 2648  Recipe: Major Weaponsmithing Crafting Trophy
#
#                                               output  \
# 0            house_housingitem_buff_fishing_bonus_t3
# 1         house_housingitem_buff_harvesting_bonus_t3
# 2            house_housingitem_buff_logging_bonus_t3
# 3               house_housingitem_buff_luck_bonus_t3
# 4           house_housingitem_buff_damage_vs_lost_t3
# 5            house_housingitem_buff_cooking_bonus_t3
# 6      house_housingitem_buff_damage_vs_corrupted_t3
# 7        house_housingitem_buff_engineering_bonus_t3
# 8             house_housingitem_buff_mining_bonus_t3
# 9           house_housingitem_buff_skinning_bonus_t3
# 10                             mediumhead_voidbentt5
# 11        house_housingitem_buff_outfitting_bonus_t3
# 12                              heavyfeet_voidbentt5
# 13                            mediumchest_voidbentt5
# 14                                  trinket_chaint51
# 15                                trinket_settingt51
# 16                 1hlongsword_voidforgedharbingert5
# 17                           2hwarhammer_yulkithirt5
# 18                              2hgreataxe_darkskyt5
# 19                     1hrapier_voidbringersrapiert5
# 20                      1hroundshield_heroesshieldt5
# 21    house_housingitem_buff_damage_vs_angryearth_t3
# 22                       1hkiteshield_heroicshieldt5
# 23                         2hspear_soulforgedspeart5
# 24                                  2hbow_warpwoodt5
# 25                    2hmusket_musketofunseenpowert5
# 26        house_housingitem_buff_damage_vs_beasts_t3
# 27                     1hthrowingaxe_axeoftheabysst5
# 28                              heavyfeet_furlinedt5
# 29                          mediumfeet_beasthuntert5
# ...                                              ...
# 2619                      2hwarhammer_sacreddemiset5
# 2620               2hstafffire_enchantedflamestafft5
# 2621           house_housingitem_pirate_bookcase01_d
# 2622                         2hgreataxe_pestilencet5
# 2623      house_housingitem_pirate_decor_curtain01_b
# 2624                              2hbow_thelookoutt5
# 2625                                        ingott51
# 2626            house_housingitem_pirate_cabinet02_c
# 2627            house_housingitem_pirate_cabinet01_c
# 2628            house_housingitem_pirate_cabinet01_d
# 2629                                 trinket_hookt51
# 2630                           mediumlegs_voidbentt5
# 2631                          mediumhands_voidbentt5
# 2632                                      leathert51
# 2633                            lighthead_voidbentt5
# 2634                                 trinket_bandt51
# 2635                           lighthands_voidbentt5
# 2636                           lightchest_voidbentt5
# 2637                                        clotht51
# 2638                                       timbert51
# 2639                            lightlegs_voidbentt5
# 2640                           mediumfeet_voidbentt5
# 2641                                        blockt51
# 2642               2hstafflife_gortanstaintedstafft5
# 2643                       2hstafffire_meteortrailt5
# 2644                1hgauntletice_crystallinecurset5
# 2645         house_housingitem_storage_t4_cheststeel
# 2646         house_housingitem_buff_alchemy_bonus_t3
# 2647                            lightfeet_voidbentt5
# 2648   house_housingitem_buff_blacksmithing_bonus_t3
#
#                                             perkBuckets  rarity  recipeLevel  \
# 0                                                    []       3          200
# 1                                                    []       3          200
# 2                                                    []       3          200
# 3                                                    []       4          200
# 4                                                    []       3          200
# 5                                                    []       3          200
# 6                                                    []       3          200
# 7                                                    []       3          200
# 8                                                    []       3          200
# 9                                                    []       3          200
# 10                                                   []       4          200
# 11                                                   []       3          200
# 12                                                   []       4          200
# 13                                                   []       4          200
# 14                                                   []       3          200
# 15                                                   []       3          200
# 16                                                   []       3          200
# 17                                                   []       4          200
# 18                                                   []       4          200
# 19                                                   []       4          200
# 20                                                   []       4          200
# 21                                                   []       3          200
# 22                                                   []       4          200
# 23                                                   []       4          200
# 24                                                   []       4          200
# 25                                                   []       4          200
# 26                                                   []       3          200
# 27                                                   []       4          200
# 28    [{'id': 'craftingattributebuckett5', 'type': '...       0          200
# 29    [{'id': 'craftingattributebuckett5', 'type': '...       0          200
# ...                                                 ...     ...          ...
# 2619                                                 []       3          196
# 2620                                                 []       3          196
# 2621                                                 []       3          196
# 2622                                                 []       3          197
# 2623                                                 []       3          196
# 2624                                                 []       3          197
# 2625                                                 []       3          200
# 2626                                                 []       3          198
# 2627                                                 []       3          199
# 2628                                                 []       3          199
# 2629                                                 []       3          200
# 2630                                                 []       4          200
# 2631                                                 []       4          200
# 2632                                                 []       3          200
# 2633                                                 []       4          200
# 2634                                                 []       3          200
# 2635                                                 []       4          200
# 2636                                                 []       4          200
# 2637                                                 []       3          200
# 2638                                                 []       3          200
# 2639                                                 []       4          200
# 2640                                                 []       4          200
# 2641                                                 []       3          200
# 2642                                                 []       2          200
# 2643                                                 []       4          200
# 2644                                                 []       4          200
# 2645                                                 []       3          200
# 2646                                                 []       3          200
# 2647                                                 []       4          200
# 2648                                                 []       3          200
#
#                                           salvageRecipe  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# 6                                                   NaN
# 7                                                   NaN
# 8                                                   NaN
# 9                                                   NaN
# 10                                                  NaN
# 11                                                  NaN
# 12                                                  NaN
# 13                                                  NaN
# 14                                                  NaN
# 15                                                  NaN
# 16    {'type': 'item', 'itemType': 'Resource', 'id':...
# 17                                                  NaN
# 18                                                  NaN
# 19                                                  NaN
# 20                                                  NaN
# 21                                                  NaN
# 22                                                  NaN
# 23                                                  NaN
# 24                                                  NaN
# 25                                                  NaN
# 26                                                  NaN
# 27                                                  NaN
# 28                                                  NaN
# 29                                                  NaN
# ...                                                 ...
# 2619                                                NaN
# 2620                                                NaN
# 2621  {'type': 'item', 'itemType': 'Resource', 'id':...
# 2622                                                NaN
# 2623  {'type': 'item', 'itemType': 'Resource', 'id':...
# 2624                                                NaN
# 2625                                                NaN
# 2626  {'type': 'item', 'itemType': 'Resource', 'id':...
# 2627  {'type': 'item', 'itemType': 'Resource', 'id':...
# 2628  {'type': 'item', 'itemType': 'Resource', 'id':...
# 2629                                                NaN
# 2630                                                NaN
# 2631                                                NaN
# 2632                                                NaN
# 2633                                                NaN
# 2634                                                NaN
# 2635                                                NaN
# 2636                                                NaN
# 2637                                                NaN
# 2638                                                NaN
# 2639                                                NaN
# 2640                                                NaN
# 2641                                                NaN
# 2642                                                NaN
# 2643                                                NaN
# 2644                                                NaN
# 2645  {'type': 'item', 'itemType': 'Resource', 'id':...
# 2646                                                NaN
# 2647                                                NaN
# 2648                                                NaN
#
#                          stations      tradeskill    type
# 0               [Workshop Tier 5]      Furnishing  recipe
# 1               [Workshop Tier 5]      Furnishing  recipe
# 2               [Workshop Tier 5]      Furnishing  recipe
# 3               [Workshop Tier 5]      Furnishing  recipe
# 4               [Workshop Tier 5]      Furnishing  recipe
# 5               [Workshop Tier 5]      Furnishing  recipe
# 6               [Workshop Tier 5]      Furnishing  recipe
# 7               [Workshop Tier 5]      Furnishing  recipe
# 8               [Workshop Tier 5]      Furnishing  recipe
# 9               [Workshop Tier 5]      Furnishing  recipe
# 10    [Outfitting Station Tier 5]        Armoring  recipe
# 11              [Workshop Tier 5]      Furnishing  recipe
# 12                 [Forge Tier 5]        Armoring  recipe
# 13    [Outfitting Station Tier 5]        Armoring  recipe
# 14    [Outfitting Station Tier 5]   Jewelcrafting  recipe
# 15    [Outfitting Station Tier 5]   Jewelcrafting  recipe
# 16                 [Forge Tier 5]  Weaponsmithing  recipe
# 17                 [Forge Tier 5]  Weaponsmithing  recipe
# 18                 [Forge Tier 5]  Weaponsmithing  recipe
# 19                 [Forge Tier 5]  Weaponsmithing  recipe
# 20                 [Forge Tier 5]  Weaponsmithing  recipe
# 21              [Workshop Tier 5]      Furnishing  recipe
# 22                 [Forge Tier 5]  Weaponsmithing  recipe
# 23                 [Forge Tier 5]     Engineering  recipe
# 24              [Workshop Tier 5]     Engineering  recipe
# 25              [Workshop Tier 5]     Engineering  recipe
# 26              [Workshop Tier 5]      Furnishing  recipe
# 27                 [Forge Tier 5]     Engineering  recipe
# 28                 [Forge Tier 5]        Armoring  recipe
# 29    [Outfitting Station Tier 5]        Armoring  recipe
# ...                           ...             ...     ...
# 2619               [Forge Tier 5]  Weaponsmithing  recipe
# 2620   [Arcane Repository Tier 5]          Arcana  recipe
# 2621            [Workshop Tier 5]      Furnishing  recipe
# 2622               [Forge Tier 5]  Weaponsmithing  recipe
# 2623            [Workshop Tier 5]      Furnishing  recipe
# 2624            [Workshop Tier 5]     Engineering  recipe
# 2625             [Smelter Tier 5]        Smelting  recipe
# 2626            [Workshop Tier 5]      Furnishing  recipe
# 2627            [Workshop Tier 5]      Furnishing  recipe
# 2628            [Workshop Tier 5]      Furnishing  recipe
# 2629  [Outfitting Station Tier 5]   Jewelcrafting  recipe
# 2630  [Outfitting Station Tier 5]        Armoring  recipe
# 2631  [Outfitting Station Tier 5]        Armoring  recipe
# 2632             [Tannery Tier 5]  Leatherworking  recipe
# 2633  [Outfitting Station Tier 5]        Armoring  recipe
# 2634  [Outfitting Station Tier 5]   Jewelcrafting  recipe
# 2635  [Outfitting Station Tier 5]        Armoring  recipe
# 2636  [Outfitting Station Tier 5]        Armoring  recipe
# 2637                [Loom Tier 5]         Weaving  recipe
# 2638            [Woodshop Tier 5]     Woodworking  recipe
# 2639  [Outfitting Station Tier 5]        Armoring  recipe
# 2640  [Outfitting Station Tier 5]        Armoring  recipe
# 2641  [Stonecutting Table Tier 5]    Stonecutting  recipe
# 2642   [Arcane Repository Tier 5]          Arcana  recipe
# 2643   [Arcane Repository Tier 5]          Arcana  recipe
# 2644   [Arcane Repository Tier 5]          Arcana  recipe
# 2645            [Workshop Tier 5]      Furnishing  recipe
# 2646            [Workshop Tier 5]      Furnishing  recipe
# 2647  [Outfitting Station Tier 5]        Armoring  recipe
# 2648            [Workshop Tier 5]      Furnishing  recipe
#
# [2649 rows x 18 columns]

# %%
# links_table = raw_recipe_table.copy(deep=True)
links_dict = dict(ChainMap(*raw_recipe_table.apply(lambda row: dict(ChainMap(*list(map(lambda x: process_links(x), row['ingredients'])))), axis=1)))

links_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in links_dict.items() ]))

# %%
links_df
# Out:
#                      Metals                Leathers         Tier 5 Cloth  \
# 0              (ingott5, 1)          (leathert5, 2)         (clotht5, 6)
# 1              (ingott2, 1)          (leathert2, 2)    (scaleclotht1, 6)
# 2            (faeiront1, 1)         (ragehidet1, 2)  (blisterweavet1, 6)
# 3              (ingott3, 1)          (leathert3, 2)        (clotht51, 6)
# 4          (voidsteelt1, 1)        (shadowfurt1, 2)                  NaN
# 5              (ingott4, 1)        (scalyhidet1, 2)                  NaN
# 6       (azuritechunkt1, 1)          (leathert4, 2)                  NaN
# 7    (blessedcruciblet1, 1)        (shifthidet1, 2)                  NaN
# 8            (tolviumt1, 1)  (brightscalehidet1, 2)                  NaN
# 9           (cinnabart1, 1)         (scarhidet1, 2)                  NaN
# 10            (ingott51, 1)      (smolderhidet1, 2)                  NaN
# 11                      NaN         (leathert51, 2)                  NaN
# 12                      NaN                     NaN                  NaN
# 13                      NaN                     NaN                  NaN
# 14                      NaN                     NaN                  NaN
# 15                      NaN                     NaN                  NaN
# 16                      NaN                     NaN                  NaN
# 17                      NaN                     NaN                  NaN
# 18                      NaN                     NaN                  NaN
# 19                      NaN                     NaN                  NaN
# 20                      NaN                     NaN                  NaN
# 21                      NaN                     NaN                  NaN
# 22                      NaN                     NaN                  NaN
# 23                      NaN                     NaN                  NaN
# 24                      NaN                     NaN                  NaN
# 25                      NaN                     NaN                  NaN
# 26                      NaN                     NaN                  NaN
# 27                      NaN                     NaN                  NaN
# 28                      NaN                     NaN                  NaN
# 29                      NaN                     NaN                  NaN
# ..                      ...                     ...                  ...
# 226                     NaN                     NaN                  NaN
# 227                     NaN                     NaN                  NaN
# 228                     NaN                     NaN                  NaN
# 229                     NaN                     NaN                  NaN
# 230                     NaN                     NaN                  NaN
# 231                     NaN                     NaN                  NaN
# 232                     NaN                     NaN                  NaN
# 233                     NaN                     NaN                  NaN
# 234                     NaN                     NaN                  NaN
# 235                     NaN                     NaN                  NaN
# 236                     NaN                     NaN                  NaN
# 237                     NaN                     NaN                  NaN
# 238                     NaN                     NaN                  NaN
# 239                     NaN                     NaN                  NaN
# 240                     NaN                     NaN                  NaN
# 241                     NaN                     NaN                  NaN
# 242                     NaN                     NaN                  NaN
# 243                     NaN                     NaN                  NaN
# 244                     NaN                     NaN                  NaN
# 245                     NaN                     NaN                  NaN
# 246                     NaN                     NaN                  NaN
# 247                     NaN                     NaN                  NaN
# 248                     NaN                     NaN                  NaN
# 249                     NaN                     NaN                  NaN
# 250                     NaN                     NaN                  NaN
# 251                     NaN                     NaN                  NaN
# 252                     NaN                     NaN                  NaN
# 253                     NaN                     NaN                  NaN
# 254                     NaN                     NaN                  NaN
# 255                     NaN                     NaN                  NaN
#
#                    Cloth      Tier 5 Leather    Tier 5 Metals  \
# 0           (clotht5, 1)      (leathert5, 6)     (ingott5, 6)
# 1           (clotht2, 1)     (scarhidet1, 6)   (tolviumt1, 6)
# 2      (shadeclotht1, 1)  (smolderhidet1, 6)  (cinnabart1, 6)
# 3           (clotht3, 1)     (leathert51, 6)    (ingott51, 6)
# 4      (phasefibert1, 1)                 NaN              NaN
# 5           (clotht4, 1)                 NaN              NaN
# 6       (scalecordt1, 1)                 NaN              NaN
# 7       (glintwoolt1, 1)                 NaN              NaN
# 8      (scaleclotht1, 1)                 NaN              NaN
# 9    (blisterweavet1, 1)                 NaN              NaN
# 10         (clotht51, 1)                 NaN              NaN
# 11                   NaN                 NaN              NaN
# 12                   NaN                 NaN              NaN
# 13                   NaN                 NaN              NaN
# 14                   NaN                 NaN              NaN
# 15                   NaN                 NaN              NaN
# 16                   NaN                 NaN              NaN
# 17                   NaN                 NaN              NaN
# 18                   NaN                 NaN              NaN
# 19                   NaN                 NaN              NaN
# 20                   NaN                 NaN              NaN
# 21                   NaN                 NaN              NaN
# 22                   NaN                 NaN              NaN
# 23                   NaN                 NaN              NaN
# 24                   NaN                 NaN              NaN
# 25                   NaN                 NaN              NaN
# 26                   NaN                 NaN              NaN
# 27                   NaN                 NaN              NaN
# 28                   NaN                 NaN              NaN
# 29                   NaN                 NaN              NaN
# ..                   ...                 ...              ...
# 226                  NaN                 NaN              NaN
# 227                  NaN                 NaN              NaN
# 228                  NaN                 NaN              NaN
# 229                  NaN                 NaN              NaN
# 230                  NaN                 NaN              NaN
# 231                  NaN                 NaN              NaN
# 232                  NaN                 NaN              NaN
# 233                  NaN                 NaN              NaN
# 234                  NaN                 NaN              NaN
# 235                  NaN                 NaN              NaN
# 236                  NaN                 NaN              NaN
# 237                  NaN                 NaN              NaN
# 238                  NaN                 NaN              NaN
# 239                  NaN                 NaN              NaN
# 240                  NaN                 NaN              NaN
# 241                  NaN                 NaN              NaN
# 242                  NaN                 NaN              NaN
# 243                  NaN                 NaN              NaN
# 244                  NaN                 NaN              NaN
# 245                  NaN                 NaN              NaN
# 246                  NaN                 NaN              NaN
# 247                  NaN                 NaN              NaN
# 248                  NaN                 NaN              NaN
# 249                  NaN                 NaN              NaN
# 250                  NaN                 NaN              NaN
# 251                  NaN                 NaN              NaN
# 252                  NaN                 NaN              NaN
# 253                  NaN                 NaN              NaN
# 254                  NaN                 NaN              NaN
# 255                  NaN                 NaN              NaN
#
#               Any Craft Mods         Gemstones        Spirit Reagents  \
# 0    (icegauntletcharmt4, 1)      (topazt4, 3)   (essencespiritt1, 1)
# 1    (icegauntletcharmt3, 1)      (topazt3, 3)   (alchemyspiritt3, 1)
# 2    (icegauntletcharmt2, 1)      (topazt2, 3)   (alchemyspiritt2, 1)
# 3    (icegauntletcharmt1, 1)      (topazt1, 3)   (alchemyspiritt1, 1)
# 4          (spearcharmt6, 1)   (sapphiret4, 3)   (dragonfishjawt5, 1)
# 5          (spearcharmt5, 1)   (sapphiret3, 3)      (soulsproutt3, 1)
# 6          (spearcharmt4, 1)   (sapphiret2, 3)      (soulsproutt2, 1)
# 7          (spearcharmt3, 1)   (sapphiret1, 3)      (soulsproutt1, 1)
# 8          (spearcharmt2, 1)       (rubyt4, 3)  (soulwyrmtonguet1, 1)
# 9          (spearcharmt1, 1)       (rubyt3, 3)   (lodestonesoult1, 1)
# 10        (rapiercharmt6, 1)       (rubyt2, 3)        (shellbedt1, 1)
# 11        (rapiercharmt5, 1)       (rubyt1, 3)         (tubecapt1, 1)
# 12        (rapiercharmt4, 1)      (pearlt4, 3)   (bumbleblossomt1, 1)
# 13        (rapiercharmt3, 1)      (pearlt3, 3)                    NaN
# 14        (rapiercharmt2, 1)      (pearlt2, 3)                    NaN
# 15        (rapiercharmt1, 1)      (pearlt1, 3)                    NaN
# 16     (firestaffcharmt6, 1)       (opalt4, 3)                    NaN
# 17     (firestaffcharmt5, 1)       (opalt3, 3)                    NaN
# 18     (firestaffcharmt4, 1)       (opalt2, 3)                    NaN
# 19     (firestaffcharmt3, 1)       (opalt1, 3)                    NaN
# 20     (firestaffcharmt2, 1)       (onyxt4, 3)                    NaN
# 21     (firestaffcharmt1, 1)       (onyxt3, 3)                    NaN
# 22     (lifestaffcharmt6, 1)       (onyxt2, 3)                    NaN
# 23     (lifestaffcharmt5, 1)       (onyxt1, 3)                    NaN
# 24     (lifestaffcharmt4, 1)  (moonstonet4, 3)                    NaN
# 25     (lifestaffcharmt3, 1)  (moonstonet3, 3)                    NaN
# 26     (lifestaffcharmt2, 1)  (moonstonet2, 3)                    NaN
# 27     (lifestaffcharmt1, 1)  (moonstonet1, 3)                    NaN
# 28        (musketcharmt6, 1)  (malachitet4, 3)                    NaN
# 29        (musketcharmt5, 1)  (malachitet3, 3)                    NaN
# ..                       ...               ...                    ...
# 226          (baetylust3, 1)               NaN                    NaN
# 227          (baetylust2, 1)               NaN                    NaN
# 228          (baetylust1, 1)               NaN                    NaN
# 229          (azothoilt3, 1)               NaN                    NaN
# 230          (azothoilt2, 1)               NaN                    NaN
# 231          (azothoilt1, 1)               NaN                    NaN
# 232      (azaleanectart3, 1)               NaN                    NaN
# 233      (azaleanectart2, 1)               NaN                    NaN
# 234      (azaleanectart1, 1)               NaN                    NaN
# 235       (armorscrapst3, 1)               NaN                    NaN
# 236       (armorscrapst2, 1)               NaN                    NaN
# 237       (armorscrapst1, 1)               NaN                    NaN
# 238      (armorercharmt3, 1)               NaN                    NaN
# 239      (armorercharmt2, 1)               NaN                    NaN
# 240      (armorercharmt1, 1)               NaN                    NaN
# 241     (arcanistcharmt3, 1)               NaN                    NaN
# 242     (arcanistcharmt2, 1)               NaN                    NaN
# 243     (arcanistcharmt1, 1)               NaN                    NaN
# 244            (animust3, 1)               NaN                    NaN
# 245            (animust2, 1)               NaN                    NaN
# 246            (animust1, 1)               NaN                    NaN
# 247    (ancientessencet3, 1)               NaN                    NaN
# 248    (ancientessencet2, 1)               NaN                    NaN
# 249    (ancientessencet1, 1)               NaN                    NaN
# 250        (adderstonet3, 1)               NaN                    NaN
# 251        (adderstonet2, 1)               NaN                    NaN
# 252        (adderstonet1, 1)               NaN                    NaN
# 253           (adamantt3, 1)               NaN                    NaN
# 254           (adamantt2, 1)               NaN                    NaN
# 255           (adamantt1, 1)               NaN                    NaN
#
#             Life Reagents     ...               Tier 2 Timber  \
# 0      (essencelifet1, 1)     ...              (timbert2, 12)
# 1      (alchemylifet3, 1)     ...       (petrifiedwoodt1, 12)
# 2      (alchemylifet2, 1)     ...                         NaN
# 3      (alchemylifet1, 1)     ...                         NaN
# 4        (lifebloomt3, 1)     ...                         NaN
# 5        (lifebloomt2, 1)     ...                         NaN
# 6        (lifebloomt1, 1)     ...                         NaN
# 7     (lifemotheyest1, 1)     ...                         NaN
# 8    (lodestonelifet1, 1)     ...                         NaN
# 9       (gillflowert1, 1)     ...                         NaN
# 10      (tanglewispt1, 1)     ...                         NaN
# 11        (spinecapt1, 1)     ...                         NaN
# 12                    NaN     ...                         NaN
# 13                    NaN     ...                         NaN
# 14                    NaN     ...                         NaN
# 15                    NaN     ...                         NaN
# 16                    NaN     ...                         NaN
# 17                    NaN     ...                         NaN
# 18                    NaN     ...                         NaN
# 19                    NaN     ...                         NaN
# 20                    NaN     ...                         NaN
# 21                    NaN     ...                         NaN
# 22                    NaN     ...                         NaN
# 23                    NaN     ...                         NaN
# 24                    NaN     ...                         NaN
# 25                    NaN     ...                         NaN
# 26                    NaN     ...                         NaN
# 27                    NaN     ...                         NaN
# 28                    NaN     ...                         NaN
# 29                    NaN     ...                         NaN
# ..                    ...     ...                         ...
# 226                   NaN     ...                         NaN
# 227                   NaN     ...                         NaN
# 228                   NaN     ...                         NaN
# 229                   NaN     ...                         NaN
# 230                   NaN     ...                         NaN
# 231                   NaN     ...                         NaN
# 232                   NaN     ...                         NaN
# 233                   NaN     ...                         NaN
# 234                   NaN     ...                         NaN
# 235                   NaN     ...                         NaN
# 236                   NaN     ...                         NaN
# 237                   NaN     ...                         NaN
# 238                   NaN     ...                         NaN
# 239                   NaN     ...                         NaN
# 240                   NaN     ...                         NaN
# 241                   NaN     ...                         NaN
# 242                   NaN     ...                         NaN
# 243                   NaN     ...                         NaN
# 244                   NaN     ...                         NaN
# 245                   NaN     ...                         NaN
# 246                   NaN     ...                         NaN
# 247                   NaN     ...                         NaN
# 248                   NaN     ...                         NaN
# 249                   NaN     ...                         NaN
# 250                   NaN     ...                         NaN
# 251                   NaN     ...                         NaN
# 252                   NaN     ...                         NaN
# 253                   NaN     ...                         NaN
# 254                   NaN     ...                         NaN
# 255                   NaN     ...                         NaN
#
#     Tier 1 Raw Foods Tier 2 Medicinal Reagents    Tier 2 Raw Foods  \
# 0        (milkt1, 1)          (lifebloomt1, 1)  (pastrycrustt1, 1)
# 1    (mushroomt1, 1)         (glowingcapt1, 1)        (pastat1, 1)
# 2         (nutt1, 1)         (gillflowert1, 1)      (sausaget1, 1)
# 3     (poultryt1, 1)           (platecapt1, 1)        (breadt1, 1)
# 4         (eggt1, 1)         (sporebloomt1, 1)       (carrott1, 1)
# 5        (fisht1, 1)                       NaN         (cornt1, 1)
# 6        (porkt1, 1)                       NaN       (squasht1, 1)
# 7    (meatgamet1, 1)                       NaN    (cranberryt1, 1)
# 8                NaN                       NaN   (strawberryt1, 1)
# 9                NaN                       NaN         (fisht2, 1)
# 10               NaN                       NaN      (redmeatt1, 1)
# 11               NaN                       NaN                 NaN
# 12               NaN                       NaN                 NaN
# 13               NaN                       NaN                 NaN
# 14               NaN                       NaN                 NaN
# 15               NaN                       NaN                 NaN
# 16               NaN                       NaN                 NaN
# 17               NaN                       NaN                 NaN
# 18               NaN                       NaN                 NaN
# 19               NaN                       NaN                 NaN
# 20               NaN                       NaN                 NaN
# 21               NaN                       NaN                 NaN
# 22               NaN                       NaN                 NaN
# 23               NaN                       NaN                 NaN
# 24               NaN                       NaN                 NaN
# 25               NaN                       NaN                 NaN
# 26               NaN                       NaN                 NaN
# 27               NaN                       NaN                 NaN
# 28               NaN                       NaN                 NaN
# 29               NaN                       NaN                 NaN
# ..               ...                       ...                 ...
# 226              NaN                       NaN                 NaN
# 227              NaN                       NaN                 NaN
# 228              NaN                       NaN                 NaN
# 229              NaN                       NaN                 NaN
# 230              NaN                       NaN                 NaN
# 231              NaN                       NaN                 NaN
# 232              NaN                       NaN                 NaN
# 233              NaN                       NaN                 NaN
# 234              NaN                       NaN                 NaN
# 235              NaN                       NaN                 NaN
# 236              NaN                       NaN                 NaN
# 237              NaN                       NaN                 NaN
# 238              NaN                       NaN                 NaN
# 239              NaN                       NaN                 NaN
# 240              NaN                       NaN                 NaN
# 241              NaN                       NaN                 NaN
# 242              NaN                       NaN                 NaN
# 243              NaN                       NaN                 NaN
# 244              NaN                       NaN                 NaN
# 245              NaN                       NaN                 NaN
# 246              NaN                       NaN                 NaN
# 247              NaN                       NaN                 NaN
# 248              NaN                       NaN                 NaN
# 249              NaN                       NaN                 NaN
# 250              NaN                       NaN                 NaN
# 251              NaN                       NaN                 NaN
# 252              NaN                       NaN                 NaN
# 253              NaN                       NaN                 NaN
# 254              NaN                       NaN                 NaN
# 255              NaN                       NaN                 NaN
#
#     Tier 2 Magical Reagents        Tier 3 Timber  Tier 3 Raw Foods  \
# 0         (soulsproutt1, 1)       (timbert3, 13)  (blueberryt1, 1)
# 1         (suncreepert1, 1)  (whisperwoodt1, 13)      (oniont1, 1)
# 2         (tanglewispt1, 1)                  NaN    (cabbaget1, 1)
# 3      (bumbleblossomt1, 1)                  NaN     (potatot1, 1)
# 4                       NaN                  NaN     (barleyt1, 1)
# 5                       NaN                  NaN      (berryt1, 1)
# 6                       NaN                  NaN      (melont1, 1)
# 7                       NaN                  NaN       (fisht3, 1)
# 8                       NaN                  NaN  (meatsquidt1, 1)
# 9                       NaN                  NaN    (hamhockt1, 1)
# 10                      NaN                  NaN    (venisont1, 1)
# 11                      NaN                  NaN               NaN
# 12                      NaN                  NaN               NaN
# 13                      NaN                  NaN               NaN
# 14                      NaN                  NaN               NaN
# 15                      NaN                  NaN               NaN
# 16                      NaN                  NaN               NaN
# 17                      NaN                  NaN               NaN
# 18                      NaN                  NaN               NaN
# 19                      NaN                  NaN               NaN
# 20                      NaN                  NaN               NaN
# 21                      NaN                  NaN               NaN
# 22                      NaN                  NaN               NaN
# 23                      NaN                  NaN               NaN
# 24                      NaN                  NaN               NaN
# 25                      NaN                  NaN               NaN
# 26                      NaN                  NaN               NaN
# 27                      NaN                  NaN               NaN
# 28                      NaN                  NaN               NaN
# 29                      NaN                  NaN               NaN
# ..                      ...                  ...               ...
# 226                     NaN                  NaN               NaN
# 227                     NaN                  NaN               NaN
# 228                     NaN                  NaN               NaN
# 229                     NaN                  NaN               NaN
# 230                     NaN                  NaN               NaN
# 231                     NaN                  NaN               NaN
# 232                     NaN                  NaN               NaN
# 233                     NaN                  NaN               NaN
# 234                     NaN                  NaN               NaN
# 235                     NaN                  NaN               NaN
# 236                     NaN                  NaN               NaN
# 237                     NaN                  NaN               NaN
# 238                     NaN                  NaN               NaN
# 239                     NaN                  NaN               NaN
# 240                     NaN                  NaN               NaN
# 241                     NaN                  NaN               NaN
# 242                     NaN                  NaN               NaN
# 243                     NaN                  NaN               NaN
# 244                     NaN                  NaN               NaN
# 245                     NaN                  NaN               NaN
# 246                     NaN                  NaN               NaN
# 247                     NaN                  NaN               NaN
# 248                     NaN                  NaN               NaN
# 249                     NaN                  NaN               NaN
# 250                     NaN                  NaN               NaN
# 251                     NaN                  NaN               NaN
# 252                     NaN                  NaN               NaN
# 253                     NaN                  NaN               NaN
# 254                     NaN                  NaN               NaN
# 255                     NaN                  NaN               NaN
#
#     Tier 3 Magical Reagents  Tier 4 Furs  Tier 5 Furs
# 0         (soulsproutt2, 1)  (furt4, 12)  (furt5, 12)
# 1      (lodestonesoult1, 1)          NaN          NaN
# 2       (frogfishtailt1, 1)          NaN          NaN
# 3         (snailslimet1, 1)          NaN          NaN
# 4    (catfishwhiskerst1, 1)          NaN          NaN
# 5    (paddlefishgillst1, 1)          NaN          NaN
# 6       (mushroomfinst1, 1)          NaN          NaN
# 7                       NaN          NaN          NaN
# 8                       NaN          NaN          NaN
# 9                       NaN          NaN          NaN
# 10                      NaN          NaN          NaN
# 11                      NaN          NaN          NaN
# 12                      NaN          NaN          NaN
# 13                      NaN          NaN          NaN
# 14                      NaN          NaN          NaN
# 15                      NaN          NaN          NaN
# 16                      NaN          NaN          NaN
# 17                      NaN          NaN          NaN
# 18                      NaN          NaN          NaN
# 19                      NaN          NaN          NaN
# 20                      NaN          NaN          NaN
# 21                      NaN          NaN          NaN
# 22                      NaN          NaN          NaN
# 23                      NaN          NaN          NaN
# 24                      NaN          NaN          NaN
# 25                      NaN          NaN          NaN
# 26                      NaN          NaN          NaN
# 27                      NaN          NaN          NaN
# 28                      NaN          NaN          NaN
# 29                      NaN          NaN          NaN
# ..                      ...          ...          ...
# 226                     NaN          NaN          NaN
# 227                     NaN          NaN          NaN
# 228                     NaN          NaN          NaN
# 229                     NaN          NaN          NaN
# 230                     NaN          NaN          NaN
# 231                     NaN          NaN          NaN
# 232                     NaN          NaN          NaN
# 233                     NaN          NaN          NaN
# 234                     NaN          NaN          NaN
# 235                     NaN          NaN          NaN
# 236                     NaN          NaN          NaN
# 237                     NaN          NaN          NaN
# 238                     NaN          NaN          NaN
# 239                     NaN          NaN          NaN
# 240                     NaN          NaN          NaN
# 241                     NaN          NaN          NaN
# 242                     NaN          NaN          NaN
# 243                     NaN          NaN          NaN
# 244                     NaN          NaN          NaN
# 245                     NaN          NaN          NaN
# 246                     NaN          NaN          NaN
# 247                     NaN          NaN          NaN
# 248                     NaN          NaN          NaN
# 249                     NaN          NaN          NaN
# 250                     NaN          NaN          NaN
# 251                     NaN          NaN          NaN
# 252                     NaN          NaN          NaN
# 253                     NaN          NaN          NaN
# 254                     NaN          NaN          NaN
# 255                     NaN          NaN          NaN
#
# [256 rows x 87 columns]

# %% [markdown]
# ### Items Table
# Now we want to pull out the ingredients from each row and make a big item table out of it.

# %%
def unwrap_dfs(table):
    rows = []
    return_table = table.apply(lambda row: rows.append(row))
    nice_return_table = pd.concat(rows)
    return nice_return_table

# %%
outputs_table = unwrap_dfs(raw_recipe_table.apply(lambda row: pd.DataFrame.from_records([row['output']]), axis=1))
outputs_table
# Out:
#                                               icon  \
# 0          House_HousingItem_Buff_Fishing_Bonus_T3
# 0       House_HousingItem_Buff_Harvesting_Bonus_T3
# 0          House_HousingItem_Buff_Logging_Bonus_T3
# 0             House_HousingItem_Buff_Luck_Bonus_T3
# 0         House_HousingItem_Buff_Damage_Vs_Lost_T3
# 0          House_HousingItem_Buff_Cooking_Bonus_T3
# 0    House_HousingItem_Buff_Damage_Vs_Corrupted_T3
# 0      House_HousingItem_Buff_Engineering_Bonus_T3
# 0           House_HousingItem_Buff_Mining_Bonus_T3
# 0         House_HousingItem_Buff_Skinning_Bonus_T3
# 0                            m_voidbentmedium_head
# 0       House_HousingItem_Buff_Outfitting_Bonus_T3
# 0                             m_voidbentheavy_feet
# 0                           m_voidbentmedium_chest
# 0                                 Trinket_ChainT51
# 0                               Trinket_SettingT51
# 0                         1hLongsword_WidowmakerT5
# 0                        2hWarhammer_EarthshakerT2
# 0                               2hGreatAxeHeroicT5
# 0                                 1hRapierHeroicT5
# 0                            1hRoundShieldHeroicT5
# 0   House_HousingItem_Buff_Damage_Vs_AngryEarth_T3
# 0                             1hKiteShieldHeroicT5
# 0                                        2hSpearT4
# 0                                    2hBowHeroicT5
# 0                                 2hMusketHeroicT5
# 0       House_HousingItem_Buff_Damage_Vs_Beasts_T3
# 0                                1hHatchetHeroicT5
# 0                               Feet_TrailrunnerT2
# 0                                  BeastBear_Boots
# ..                                             ...
# 0                        2hWarhammer_EarthshakerT2
# 0                      2hStaffFire_TormentedSoulT4
# 0            House_HousingItem_Pirate_Bookcase01_D
# 0                     2hGreataxe_RecklessAbandonT4
# 0       House_HousingItem_Pirate_Decor_Curtain01_B
# 0                                       2hBowFaeT5
# 0                                         IngotT51
# 0             House_HousingItem_Pirate_Cabinet02_C
# 0             House_HousingItem_Pirate_Cabinet01_C
# 0             House_HousingItem_Pirate_Cabinet01_D
# 0                                  Trinket_HookT51
# 0                            m_voidbentmedium_legs
# 0                          m_voidbentmedium_gloves
# 0                                       LeatherT51
# 0                             m_voidbentlight_head
# 0                                  Trinket_BandT51
# 0                           m_voidbentlight_gloves
# 0                            m_voidbentlight_chest
# 0                                         ClothT51
# 0                                        TimberT51
# 0                             m_voidbentlight_legs
# 0                            m_voidbentmedium_feet
# 0                                         BlockT51
# 0                      2hStaffLife_PeacefulDreamT2
# 0                      2hStaffFire_TormentedSoulT4
# 0                          2hicegauntletEtherealT5
# 0          House_HousingItem_Storage_T4_ChestSteel
# 0          House_HousingItem_Buff_Alchemy_Bonus_T3
# 0                             m_voidbentlight_feet
# 0    House_HousingItem_Buff_Blacksmithing_Bonus_T3
#
#                                                 id     itemType  \
# 0          house_housingitem_buff_fishing_bonus_t3  HousingItem
# 0       house_housingitem_buff_harvesting_bonus_t3  HousingItem
# 0          house_housingitem_buff_logging_bonus_t3  HousingItem
# 0             house_housingitem_buff_luck_bonus_t3  HousingItem
# 0         house_housingitem_buff_damage_vs_lost_t3  HousingItem
# 0          house_housingitem_buff_cooking_bonus_t3  HousingItem
# 0    house_housingitem_buff_damage_vs_corrupted_t3  HousingItem
# 0      house_housingitem_buff_engineering_bonus_t3  HousingItem
# 0           house_housingitem_buff_mining_bonus_t3  HousingItem
# 0         house_housingitem_buff_skinning_bonus_t3  HousingItem
# 0                            mediumhead_voidbentt5        Armor
# 0       house_housingitem_buff_outfitting_bonus_t3  HousingItem
# 0                             heavyfeet_voidbentt5        Armor
# 0                           mediumchest_voidbentt5        Armor
# 0                                 trinket_chaint51     Resource
# 0                               trinket_settingt51     Resource
# 0                1hlongsword_voidforgedharbingert5       Weapon
# 0                          2hwarhammer_yulkithirt5       Weapon
# 0                             2hgreataxe_darkskyt5       Weapon
# 0                    1hrapier_voidbringersrapiert5       Weapon
# 0                     1hroundshield_heroesshieldt5       Weapon
# 0   house_housingitem_buff_damage_vs_angryearth_t3  HousingItem
# 0                      1hkiteshield_heroicshieldt5       Weapon
# 0                        2hspear_soulforgedspeart5       Weapon
# 0                                 2hbow_warpwoodt5       Weapon
# 0                   2hmusket_musketofunseenpowert5       Weapon
# 0       house_housingitem_buff_damage_vs_beasts_t3  HousingItem
# 0                    1hthrowingaxe_axeoftheabysst5       Weapon
# 0                             heavyfeet_furlinedt5        Armor
# 0                         mediumfeet_beasthuntert5        Armor
# ..                                             ...          ...
# 0                       2hwarhammer_sacreddemiset5       Weapon
# 0                2hstafffire_enchantedflamestafft5       Weapon
# 0            house_housingitem_pirate_bookcase01_d  HousingItem
# 0                          2hgreataxe_pestilencet5       Weapon
# 0       house_housingitem_pirate_decor_curtain01_b  HousingItem
# 0                               2hbow_thelookoutt5       Weapon
# 0                                         ingott51     Resource
# 0             house_housingitem_pirate_cabinet02_c  HousingItem
# 0             house_housingitem_pirate_cabinet01_c  HousingItem
# 0             house_housingitem_pirate_cabinet01_d  HousingItem
# 0                                  trinket_hookt51     Resource
# 0                            mediumlegs_voidbentt5        Armor
# 0                           mediumhands_voidbentt5        Armor
# 0                                       leathert51     Resource
# 0                             lighthead_voidbentt5        Armor
# 0                                  trinket_bandt51     Resource
# 0                            lighthands_voidbentt5        Armor
# 0                            lightchest_voidbentt5        Armor
# 0                                         clotht51     Resource
# 0                                        timbert51     Resource
# 0                             lightlegs_voidbentt5        Armor
# 0                            mediumfeet_voidbentt5        Armor
# 0                                         blockt51     Resource
# 0                2hstafflife_gortanstaintedstafft5       Weapon
# 0                        2hstafffire_meteortrailt5       Weapon
# 0                 1hgauntletice_crystallinecurset5       Weapon
# 0          house_housingitem_storage_t4_cheststeel  HousingItem
# 0          house_housingitem_buff_alchemy_bonus_t3  HousingItem
# 0                             lightfeet_voidbentt5        Armor
# 0    house_housingitem_buff_blacksmithing_bonus_t3  HousingItem
#
#                                     name  quantity  rarity  type
# 0         Major Fishing Gathering Trophy         1       3  item
# 0      Major Harvesting Gathering Trophy         1       3  item
# 0         Major Logging Gathering Trophy         1       3  item
# 0                 Major Loot Luck Trophy         1       4  item
# 0               Major Lost Combat Trophy         1       3  item
# 0          Major Cooking Crafting Trophy         1       3  item
# 0          Major Corrupted Combat Trophy         1       3  item
# 0      Major Engineering Crafting Trophy         1       3  item
# 0          Major Mining Gathering Trophy         1       3  item
# 0        Major Skinning Gathering Trophy         1       3  item
# 0                           Voidbent Hat         1       4  item
# 0         Major Armoring Crafting Trophy         1       3  item
# 0                      Voidbent Sabatons         1       4  item
# 0                          Voidbent Coat         1       4  item
# 0                         Asmodeum Chain         1       3  item
# 0                       Asmodeum Setting         1       3  item
# 0                   Voidforged Harbinger         1       3  item
# 0                             Yul'kithir         1       4  item
# 0                               Dark Sky         1       4  item
# 0                   Voidbringer's Rapier         1       4  item
# 0                         Gilded Defense         1       4  item
# 0        Major Angry Earth Combat Trophy         1       3  item
# 0                   Shield of Suppresion         1       4  item
# 0                       Soulforged Spear         1       4  item
# 0                               Warpwood         1       4  item
# 0                 Musket of Unseen Power         1       4  item
# 0           Major Wildlife Combat Trophy         1       3  item
# 0                       Axe of the Abyss         1       4  item
# 0             Fur-Lined Orichalcum Boots         1       0  item
# 0                  Beasthunter Footwraps         1       0  item
# ..                                   ...       ...     ...   ...
# 0                          Sacred Demise         1       3  item
# 0                  Enchanted Flame Staff         1       3  item
# 0           Black-lacquered Low Bookcase         1       3  item
# 0                             Pestilence         1       3  item
# 0                   Seafoam Posh Valance         1       3  item
# 0                            The Lookout         1       3  item
# 0                               Asmodeum         1       3  item
# 0             Well-polished Tall Dresser         1       3  item
# 0            Well-polished Short Dresser         1       3  item
# 0          Black-lacquered Short Dresser         1       3  item
# 0                          Asmodeum Hook         1       3  item
# 0                      Voidbent Leggings         1       4  item
# 0                         Voidbent Grips         1       4  item
# 0                          Runic Leather         1       3  item
# 0                         Voidbent Wraps         1       4  item
# 0                          Asmodeum Band         1       3  item
# 0                        Voidbent Gloves         1       4  item
# 0                         Voidbent Robes         1       4  item
# 0                           Phoenixweave         1       3  item
# 0                       Glittering Ebony         1       3  item
# 0                         Voidbent Pants         1       4  item
# 0                         Voidbent Boots         1       4  item
# 0                              Runestone         1       3  item
# 0                 Gortan's Tainted Staff         1       2  item
# 0                           Meteor Trail         1       4  item
# 0                      Crystalline Curse         1       4  item
# 0             Golden Steel Storage Chest         1       3  item
# 0           Major Arcana Crafting Trophy         1       3  item
# 0                         Voidbent Shoes         1       4  item
# 0   Major Weaponsmithing Crafting Trophy         1       3  item
#
# [2649 rows x 7 columns]

# %%
def do_thing(row, rows):
    for i in range(0,7):
        if isinstance(row[i], dict):
            append_rows(row, rows, i)
    return row
def append_rows(row, rows, idx):
#     print("Row: ", idx, type(row[idx]), type(pd.DataFrame.from_records([row[idx]])), row[idx],)
    rows.append(pd.DataFrame.from_records([row[idx]]))
def unwrap_ingredients(table):
    rows = []
    return_table = table.apply(lambda row: do_thing(row, rows), axis=1)
    nice_return_table = pd.concat(rows, sort=True)
    return nice_return_table
ingredients_table = unwrap_ingredients(
    unwrap_dfs(
        raw_recipe_table.apply(
            lambda row: pd.DataFrame.from_records([row['ingredients']]), axis=1)))

# %%
items_table = pd.concat([outputs_table, ingredients_table])
# Out:
# /Users/eric/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
items_table
# Out:
#                                               icon  \
# 0          House_HousingItem_Buff_Fishing_Bonus_T3
# 0       House_HousingItem_Buff_Harvesting_Bonus_T3
# 0          House_HousingItem_Buff_Logging_Bonus_T3
# 0             House_HousingItem_Buff_Luck_Bonus_T3
# 0         House_HousingItem_Buff_Damage_Vs_Lost_T3
# 0          House_HousingItem_Buff_Cooking_Bonus_T3
# 0    House_HousingItem_Buff_Damage_Vs_Corrupted_T3
# 0      House_HousingItem_Buff_Engineering_Bonus_T3
# 0           House_HousingItem_Buff_Mining_Bonus_T3
# 0         House_HousingItem_Buff_Skinning_Bonus_T3
# 0                            m_voidbentmedium_head
# 0       House_HousingItem_Buff_Outfitting_Bonus_T3
# 0                             m_voidbentheavy_feet
# 0                           m_voidbentmedium_chest
# 0                                 Trinket_ChainT51
# 0                               Trinket_SettingT51
# 0                         1hLongsword_WidowmakerT5
# 0                        2hWarhammer_EarthshakerT2
# 0                               2hGreatAxeHeroicT5
# 0                                 1hRapierHeroicT5
# 0                            1hRoundShieldHeroicT5
# 0   House_HousingItem_Buff_Damage_Vs_AngryEarth_T3
# 0                             1hKiteShieldHeroicT5
# 0                                        2hSpearT4
# 0                                    2hBowHeroicT5
# 0                                 2hMusketHeroicT5
# 0       House_HousingItem_Buff_Damage_Vs_Beasts_T3
# 0                                1hHatchetHeroicT5
# 0                               Feet_TrailrunnerT2
# 0                                  BeastBear_Boots
# ..                                             ...
# 0                                  WrithingVinesT3
# 0                                 CorruptedClothT3
# 0                                   EssenceWaterT1
# 0                                       LeatherT51
# 0                                         BlockT51
# 0                                 CoreCrystalIceT5
# 0                                        CrystalT3
# 0                                  WrithingVinesT3
# 0                                 CorruptedClothT3
# 0                                         TimberT5
# 0                                          IngotT5
# 0                                      WoodStainT5
# 0                                    HoldingRuneT5
# 0                                         TimberT5
# 0                                          IngotT5
# 0                                      WoodStainT5
# 0                                  DispellingKitT5
# 0          House_HousingItem_Buff_Alchemy_Bonus_T2
# 0                                         ClothT51
# 0                                       LeatherT51
# 0                                         IngotT51
# 0                                    RunicThreadT5
# 0                                    VoidbentIngot
# 0                                         MI_Cloak
# 0                                 CorruptedClothT3
# 0                                         TimberT5
# 0                                          IngotT5
# 0                                      WoodStainT5
# 0                               MI_LargeSilverCoin
# 0    House_HousingItem_Buff_Blacksmithing_Bonus_T2
#
#                                                 id     itemType  \
# 0          house_housingitem_buff_fishing_bonus_t3  HousingItem
# 0       house_housingitem_buff_harvesting_bonus_t3  HousingItem
# 0          house_housingitem_buff_logging_bonus_t3  HousingItem
# 0             house_housingitem_buff_luck_bonus_t3  HousingItem
# 0         house_housingitem_buff_damage_vs_lost_t3  HousingItem
# 0          house_housingitem_buff_cooking_bonus_t3  HousingItem
# 0    house_housingitem_buff_damage_vs_corrupted_t3  HousingItem
# 0      house_housingitem_buff_engineering_bonus_t3  HousingItem
# 0           house_housingitem_buff_mining_bonus_t3  HousingItem
# 0         house_housingitem_buff_skinning_bonus_t3  HousingItem
# 0                            mediumhead_voidbentt5        Armor
# 0       house_housingitem_buff_outfitting_bonus_t3  HousingItem
# 0                             heavyfeet_voidbentt5        Armor
# 0                           mediumchest_voidbentt5        Armor
# 0                                 trinket_chaint51     Resource
# 0                               trinket_settingt51     Resource
# 0                1hlongsword_voidforgedharbingert5       Weapon
# 0                          2hwarhammer_yulkithirt5       Weapon
# 0                             2hgreataxe_darkskyt5       Weapon
# 0                    1hrapier_voidbringersrapiert5       Weapon
# 0                     1hroundshield_heroesshieldt5       Weapon
# 0   house_housingitem_buff_damage_vs_angryearth_t3  HousingItem
# 0                      1hkiteshield_heroicshieldt5       Weapon
# 0                        2hspear_soulforgedspeart5       Weapon
# 0                                 2hbow_warpwoodt5       Weapon
# 0                   2hmusket_musketofunseenpowert5       Weapon
# 0       house_housingitem_buff_damage_vs_beasts_t3  HousingItem
# 0                    1hthrowingaxe_axeoftheabysst5       Weapon
# 0                             heavyfeet_furlinedt5        Armor
# 0                         mediumfeet_beasthuntert5        Armor
# ..                                             ...          ...
# 0                                       wildwoodt1     Resource
# 0                                   blisterweavet1     Resource
# 0                                   essencewatert1     Resource
# 0                                       leathert51     Resource
# 0                                         blockt51     Resource
# 0                                 corecrystalicet5     Resource
# 0                                     eternalicet1     Resource
# 0                                       wildwoodt1     Resource
# 0                                   blisterweavet1     Resource
# 0                                         timbert5     Resource
# 0                                          ingott5     Resource
# 0                                      woodstaint5     Resource
# 0                                    holdingrunet5     Resource
# 0                                         timbert5     Resource
# 0                                          ingott5     Resource
# 0                                      woodstaint5     Resource
# 0                              philosophersstonet1     Resource
# 0          house_housingitem_buff_alchemy_bonus_t2  HousingItem
# 0                                         clotht51     Resource
# 0                                       leathert51     Resource
# 0                                         ingott51     Resource
# 0                                    runicthreadt5     Resource
# 0                                    voidbentingot     Resource
# 0                                     scaleclotht1     Resource
# 0                                   blisterweavet1     Resource
# 0                                         timbert5     Resource
# 0                                          ingott5     Resource
# 0                                      woodstaint5     Resource
# 0                              forgemastersnotest1     Resource
# 0    house_housingitem_buff_blacksmithing_bonus_t2  HousingItem
#
#                                     name quantity  rarity subIngredients  type
# 0         Major Fishing Gathering Trophy        1     3.0            NaN  item
# 0      Major Harvesting Gathering Trophy        1     3.0            NaN  item
# 0         Major Logging Gathering Trophy        1     3.0            NaN  item
# 0                 Major Loot Luck Trophy        1     4.0            NaN  item
# 0               Major Lost Combat Trophy        1     3.0            NaN  item
# 0          Major Cooking Crafting Trophy        1     3.0            NaN  item
# 0          Major Corrupted Combat Trophy        1     3.0            NaN  item
# 0      Major Engineering Crafting Trophy        1     3.0            NaN  item
# 0          Major Mining Gathering Trophy        1     3.0            NaN  item
# 0        Major Skinning Gathering Trophy        1     3.0            NaN  item
# 0                           Voidbent Hat        1     4.0            NaN  item
# 0         Major Armoring Crafting Trophy        1     3.0            NaN  item
# 0                      Voidbent Sabatons        1     4.0            NaN  item
# 0                          Voidbent Coat        1     4.0            NaN  item
# 0                         Asmodeum Chain        1     3.0            NaN  item
# 0                       Asmodeum Setting        1     3.0            NaN  item
# 0                   Voidforged Harbinger        1     3.0            NaN  item
# 0                             Yul'kithir        1     4.0            NaN  item
# 0                               Dark Sky        1     4.0            NaN  item
# 0                   Voidbringer's Rapier        1     4.0            NaN  item
# 0                         Gilded Defense        1     4.0            NaN  item
# 0        Major Angry Earth Combat Trophy        1     3.0            NaN  item
# 0                   Shield of Suppresion        1     4.0            NaN  item
# 0                       Soulforged Spear        1     4.0            NaN  item
# 0                               Warpwood        1     4.0            NaN  item
# 0                 Musket of Unseen Power        1     4.0            NaN  item
# 0           Major Wildlife Combat Trophy        1     3.0            NaN  item
# 0                       Axe of the Abyss        1     4.0            NaN  item
# 0             Fur-Lined Orichalcum Boots        1     0.0            NaN  item
# 0                  Beasthunter Footwraps        1     0.0            NaN  item
# ..                                   ...      ...     ...            ...   ...
# 0                               Wildwood        4     4.0            NaN  item
# 0                           Blisterweave        2     4.0            NaN  item
# 0                     Water Quintessence       20     3.0            NaN  item
# 0                          Runic Leather       15     3.0            NaN  item
# 0                              Runestone        5     3.0            NaN  item
# 0                       Ice Crystal Core        1     4.0            NaN  item
# 0                            Eternal Ice        1     4.0            NaN  item
# 0                               Wildwood        4     4.0            NaN  item
# 0                           Blisterweave        2     4.0            NaN  item
# 0                        Ironwood Planks       30     0.0            NaN  item
# 0                       Orichalcum Ingot       15     0.0            NaN  item
# 0                         Mahogany Stain        1     3.0            NaN  item
# 0                  Grand Rune of Holding        1     3.0            NaN  item
# 0                        Ironwood Planks       25     0.0            NaN  item
# 0                       Orichalcum Ingot       20     0.0            NaN  item
# 0                         Mahogany Stain        1     3.0            NaN  item
# 0                    Philosopher's Stone        1     4.0            NaN  item
# 0           Basic Arcana Crafting Trophy        1     2.0            NaN  item
# 0                           Phoenixweave        6     3.0            NaN  item
# 0                          Runic Leather        2     3.0            NaN  item
# 0                               Asmodeum        1     3.0            NaN  item
# 0                           Runic Thread        2     4.0            NaN  item
# 0                         Voidbent Ingot        1     4.0            NaN  item
# 0                             Scalecloth        4     4.0            NaN  item
# 0                           Blisterweave        2     4.0            NaN  item
# 0                        Ironwood Planks       25     0.0            NaN  item
# 0                       Orichalcum Ingot       20     0.0            NaN  item
# 0                         Mahogany Stain        1     3.0            NaN  item
# 0                    Forgemaster's Notes        1     4.0            NaN  item
# 0   Basic Weaponsmithing Crafting Trophy        1     2.0            NaN  item
#
# [11638 rows x 8 columns]

# %% [markdown]
# ### Create a table with the sub-ingredient links (Tier 5 Metals contains X, Y, Z)
# Maybe do this when we do the recipe trawling too. Needs to be done on the raw recipe table.

# %% [markdown]
# ### Save our nice tables so we don't have to do this again

# %%
linked_recipe_table.to_csv('data/recipe_table.csv')

# %%
items_table.to_csv('data/items_table.csv')

# %%
links_df.to_csv('data/links_table.csv')

# %%
import pickle as pkl

# %%
def save_obj(obj, name ):
    with open(name, 'wb') as f:
        pkl.dump(obj, f, pkl.HIGHEST_PROTOCOL)
        
def load_obj(name):
    with open(name, 'rb') as f:
        return pickle.load(f)

# %%
save_obj(links_dict, 'data/links_dict.pkl')
